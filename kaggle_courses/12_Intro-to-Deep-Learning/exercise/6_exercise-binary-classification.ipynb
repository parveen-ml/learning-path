# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *
# Out:
# /tmp/ipykernel_34/3338970720.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')
])

# Check your answer
q_1.check()
# Out:
# 2025-07-14 17:44:01.228649: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-14 17:44:01.228820: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-14 17:44:01.354271: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['binary_accuracy'])

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1752515069.680194      98 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 175/175 [==============================] - 6s 7ms/step - loss: 0.4876 - binary_accuracy: 0.7690 - val_loss: 0.4314 - val_binary_accuracy: 0.7991
# Epoch 2/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4230 - binary_accuracy: 0.8009 - val_loss: 0.4029 - val_binary_accuracy: 0.8098
# Epoch 3/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4108 - binary_accuracy: 0.8065 - val_loss: 0.3961 - val_binary_accuracy: 0.8176
# Epoch 4/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4032 - binary_accuracy: 0.8109 - val_loss: 0.3919 - val_binary_accuracy: 0.8204
# Epoch 5/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3972 - binary_accuracy: 0.8131 - val_loss: 0.3853 - val_binary_accuracy: 0.8221
# Epoch 6/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3939 - binary_accuracy: 0.8160 - val_loss: 0.3839 - val_binary_accuracy: 0.8237
# Epoch 7/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3878 - binary_accuracy: 0.8190 - val_loss: 0.3805 - val_binary_accuracy: 0.8271
# Epoch 8/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3866 - binary_accuracy: 0.8202 - val_loss: 0.3792 - val_binary_accuracy: 0.8270
# Epoch 9/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3819 - binary_accuracy: 0.8220 - val_loss: 0.3743 - val_binary_accuracy: 0.8285
# Epoch 10/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3801 - binary_accuracy: 0.8232 - val_loss: 0.3723 - val_binary_accuracy: 0.8320
# Epoch 11/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3774 - binary_accuracy: 0.8245 - val_loss: 0.3695 - val_binary_accuracy: 0.8312
# Epoch 12/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3738 - binary_accuracy: 0.8256 - val_loss: 0.3688 - val_binary_accuracy: 0.8340
# Epoch 13/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3726 - binary_accuracy: 0.8270 - val_loss: 0.3657 - val_binary_accuracy: 0.8339
# Epoch 14/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3696 - binary_accuracy: 0.8279 - val_loss: 0.3641 - val_binary_accuracy: 0.8346
# Epoch 15/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3680 - binary_accuracy: 0.8300 - val_loss: 0.3639 - val_binary_accuracy: 0.8360
# Epoch 16/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3659 - binary_accuracy: 0.8306 - val_loss: 0.3631 - val_binary_accuracy: 0.8371
# Epoch 17/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3638 - binary_accuracy: 0.8320 - val_loss: 0.3605 - val_binary_accuracy: 0.8378
# Epoch 18/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3612 - binary_accuracy: 0.8323 - val_loss: 0.3628 - val_binary_accuracy: 0.8354
# Epoch 19/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3605 - binary_accuracy: 0.8335 - val_loss: 0.3627 - val_binary_accuracy: 0.8366
# Epoch 20/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3584 - binary_accuracy: 0.8327 - val_loss: 0.3612 - val_binary_accuracy: 0.8368
# Epoch 21/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3571 - binary_accuracy: 0.8352 - val_loss: 0.3593 - val_binary_accuracy: 0.8370
# Epoch 22/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3551 - binary_accuracy: 0.8355 - val_loss: 0.3578 - val_binary_accuracy: 0.8384
# Epoch 23/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3547 - binary_accuracy: 0.8360 - val_loss: 0.3558 - val_binary_accuracy: 0.8381
# Epoch 24/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3536 - binary_accuracy: 0.8364 - val_loss: 0.3569 - val_binary_accuracy: 0.8382
# Epoch 25/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3521 - binary_accuracy: 0.8360 - val_loss: 0.3563 - val_binary_accuracy: 0.8390
# Epoch 26/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3510 - binary_accuracy: 0.8368 - val_loss: 0.3592 - val_binary_accuracy: 0.8363
# Epoch 27/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3499 - binary_accuracy: 0.8377 - val_loss: 0.3544 - val_binary_accuracy: 0.8392
# Epoch 28/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3489 - binary_accuracy: 0.8380 - val_loss: 0.3542 - val_binary_accuracy: 0.8399
# Epoch 29/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3476 - binary_accuracy: 0.8393 - val_loss: 0.3604 - val_binary_accuracy: 0.8359
# Epoch 30/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3463 - binary_accuracy: 0.8397 - val_loss: 0.3547 - val_binary_accuracy: 0.8391
# Epoch 31/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3462 - binary_accuracy: 0.8399 - val_loss: 0.3546 - val_binary_accuracy: 0.8377
# Epoch 32/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3435 - binary_accuracy: 0.8410 - val_loss: 0.3528 - val_binary_accuracy: 0.8399
# Epoch 33/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3440 - binary_accuracy: 0.8420 - val_loss: 0.3523 - val_binary_accuracy: 0.8418
# Epoch 34/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3416 - binary_accuracy: 0.8416 - val_loss: 0.3513 - val_binary_accuracy: 0.8415
# Epoch 35/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3415 - binary_accuracy: 0.8420 - val_loss: 0.3525 - val_binary_accuracy: 0.8411
# Epoch 36/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3406 - binary_accuracy: 0.8412 - val_loss: 0.3514 - val_binary_accuracy: 0.8410
# Epoch 37/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3400 - binary_accuracy: 0.8427 - val_loss: 0.3499 - val_binary_accuracy: 0.8415
# Epoch 38/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3387 - binary_accuracy: 0.8430 - val_loss: 0.3506 - val_binary_accuracy: 0.8415
# Epoch 39/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3390 - binary_accuracy: 0.8423 - val_loss: 0.3531 - val_binary_accuracy: 0.8396
# Epoch 40/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3366 - binary_accuracy: 0.8442 - val_loss: 0.3539 - val_binary_accuracy: 0.8412
# Epoch 41/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3368 - binary_accuracy: 0.8445 - val_loss: 0.3488 - val_binary_accuracy: 0.8425
# Epoch 42/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3360 - binary_accuracy: 0.8442 - val_loss: 0.3490 - val_binary_accuracy: 0.8421
# Epoch 43/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3363 - binary_accuracy: 0.8444 - val_loss: 0.3492 - val_binary_accuracy: 0.8427
# Epoch 44/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3343 - binary_accuracy: 0.8450 - val_loss: 0.3513 - val_binary_accuracy: 0.8407
# Epoch 45/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3347 - binary_accuracy: 0.8453 - val_loss: 0.3487 - val_binary_accuracy: 0.8414
# Epoch 46/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3335 - binary_accuracy: 0.8451 - val_loss: 0.3492 - val_binary_accuracy: 0.8419
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
